# %% [markdown]
# ### Directions
#     - The data required for this task has been provided in the file 'data.csv'
#     - Read the questions provided for each cell and assign your answers to respective variables provided in the following cell.
#     - If answers are floating point numbers round of updo two floating point after the decimal
#       - for example 10.546 should be read as 10.55, 10.544 as 10.54 and 10.1 as 10.10
#     - pandas and numpy packages are preinstalled for this task which should be sufficient to complete this task.
#     - If you need any other additional package run !pip3 install <package_name> --user in a new cell.
#     - You can either try out the solution in the same notebook or free to create additional notebook, but make sure you come back to this notebook to answer the questions.
#     - Please dont change variable name meant to assign your answers.
#     - You can create a new notebook to write your scripts for EDA and use this notebook to assign the answers.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %% [markdown]
# ### What is the standard deviation of maximum windspeed across all the days

# %%
max_windspeed = df['Maximum windspeed (mph)']
df.std().round(2)
#max_windspeed.std()
# Out:
# Average temperature (°F)     15.19
# Average humidity (%)         17.50
# Average dewpoint (°F)        14.65
# Average barometer (in)        0.25
# Average windspeed (mph)       4.09
# Average gustspeed (mph)      15.23
# Average direction (°deg)    101.06
# Rainfall for month (in)       0.63
# Rainfall for year (in)        4.70
# Maximum rain per minute       0.01
# Maximum temperature (°F)     17.61
# Minimum temperature (°F)     14.03
# Maximum humidity (%)         18.14
# Minimum humidity (%)         15.41
# Maximum pressure              0.26
# Minimum pressure              0.48
# Maximum windspeed (mph)      13.06
# Maximum gust speed (mph)     41.85
# Maximum heat index (°F)      17.84
# dtype: float64

# %% [markdown]
# ### What is the difference between 50th percentile and 75th percentile of average temperature

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
avg_temperature = df['Average temperature (°F)']
avg_temperature.head()
# Out:
# 0    37.8
# 1    43.2
# 2    25.7
# 3     9.3
# 4    23.5
# Name: Average temperature (°F), dtype: float64

# %%
avg_temperature.quantile(0.5)
# Out:
# 45.9

# %%
avg_temperature.quantile(0.75)
# Out:
# 58.1

# %%
round(avg_temperature.quantile(0.75) - avg_temperature.quantile(0.5), 2)
# Out:
# 12.2

# %% [markdown]
# ### What is the pearson correlation between average dew point and average temperature

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
test = df[['Average dewpoint (°F)', 'Average temperature (°F)']]
test.head()
# Out:
#    Average dewpoint (°F)  Average temperature (°F)
# 0                   12.7                      37.8
# 1                   14.7                      43.2
# 2                   12.7                      25.7
# 3                    0.1                       9.3
# 4                   -5.3                      23.5

# %%
test.corr(method ='pearson').round(2)
# Out:
#                           Average dewpoint (°F)  Average temperature (°F)
# Average dewpoint (°F)                      1.00                      0.76
# Average temperature (°F)                   0.76                      1.00

# %% [markdown]
# ### Out of all the available records which month has the lowest average humidity.
#     - Assign your answer as month index, for example if its July index is 7

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
test = df[['Day', 'Average humidity (%)']]
test.head()
# Out:
#          Day  Average humidity (%)
# 0  1/01/2009                    35
# 1  2/01/2009                    32
# 2  3/01/2009                    60
# 3  4/01/2009                    67
# 4  5/01/2009                    30

# %%
test_avg_hum = df['Average humidity (%)']
test_avg_hum.head()
# Out:
# 0    35
# 1    32
# 2    60
# 3    67
# 4    30
# Name: Average humidity (%), dtype: int64

# %%
min(test_avg_hum)
# Out:
# 9

# %%
test_avg_hum[test_avg_hum == 9]
# Out:
# 1300    9
# 1301    9
# 1619    9
# Name: Average humidity (%), dtype: int64

# %%
test.iloc[[1300, 1301, 1619]]
# Out:
#              Day  Average humidity (%)
# 1300  22/01/2013                     9
# 1301  23/01/2013                     9
# 1619  21/01/2014                     9

# %% [markdown]
# ### Which month has the highest median for maximum_gust_speed out of all the available records. Also find the repective value
#     - hint: group by month

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
test = df[['Day', 'Maximum gust speed (mph)']]
test.head()
# Out:
#          Day  Maximum gust speed (mph)
# 0  1/01/2009                      59.0
# 1  2/01/2009                      51.0
# 2  3/01/2009                      38.0
# 3  4/01/2009                      20.0
# 4  5/01/2009                      53.0

# %%
test_1 = test['Day']
test_1.head()
# Out:
# 0    1/01/2009
# 1    2/01/2009
# 2    3/01/2009
# 3    4/01/2009
# 4    5/01/2009
# Name: Day, dtype: object

# %%
test["month"] = [item[-7:-5] for item in test['Day']]
test.head()
# Out:
# /home/user/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          Day  Maximum gust speed (mph) month
# 0  1/01/2009                      59.0    01
# 1  2/01/2009                      51.0    01
# 2  3/01/2009                      38.0    01
# 3  4/01/2009                      20.0    01
# 4  5/01/2009                      53.0    01

# %%
test_groups = test.groupby(test['month'])
test_groups.median()
# Out:
#        Maximum gust speed (mph)
# month
# 01                         32.2
# 02                         34.5
# 03                         31.1
# 04                         27.6
# 05                         26.0
# 06                         26.5
# 07                         24.2
# 08                         24.2
# 09                         24.2
# 10                         26.5
# 11                         32.2
# 12                         33.4

# %% [markdown]
# ### Determine the average temperature between the months of March 2010 to May 2012 (including both the months)

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
df[df['Day'] == '1/03/2010']
# Out:
#            Day  Average temperature (°F)  Average humidity (%)  \
# 390  1/03/2010                      26.1                    74
#
#      Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 390                   18.4                    30.2                      2.2
#
#      Average gustspeed (mph)  Average direction (°deg)  \
# 390                      3.4                        53
#
#      Rainfall for month (in)  Rainfall for year (in)  \
# 390                     0.02                    0.59
#
#      Maximum rain per minute   Maximum temperature (°F)  \
# 390                      0.01                      39.1
#
#      Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 390                      14.3                    90                    40
#
#      Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 390             30.375             30.086                     15.0
#
#      Maximum gust speed (mph)  Maximum heat index (°F)
# 390                      22.0                     39.1

# %%
df[df['Day'] == '31/05/2012']
# Out:
#              Day  Average temperature (°F)  Average humidity (%)  \
# 1064  31/05/2012                      51.3                    55
#
#       Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 1064                   34.6                    29.9                      3.0
#
#       Average gustspeed (mph)  Average direction (°deg)  \
# 1064                      4.9                        59
#
#       Rainfall for month (in)  Rainfall for year (in)  \
# 1064                     1.22                    2.14
#
#       Maximum rain per minute   Maximum temperature (°F)  \
# 1064                       0.0                      64.2
#
#       Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 1064                      34.9                    83                    33
#
#       Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 1064             29.946             29.807                     13.8
#
#       Maximum gust speed (mph)  Maximum heat index (°F)
# 1064                      19.6                     64.2

# %%
test = df[390:1065]
test.head()
# Out:
#            Day  Average temperature (°F)  Average humidity (%)  \
# 390  1/03/2010                      26.1                    74
# 391  2/03/2010                      27.8                    58
# 392  3/03/2010                      31.4                    56
# 393  4/03/2010                      29.9                    63
# 394  5/03/2010                      29.9                    59
#
#      Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 390                   18.4                    30.2                      2.2
# 391                   12.9                    30.2                      1.4
# 392                   15.5                    30.0                      4.5
# 393                   17.9                    30.0                      1.6
# 394                   16.3                    29.9                     10.1
#
#      Average gustspeed (mph)  Average direction (°deg)  \
# 390                      3.4                        53
# 391                      2.4                        91
# 392                      6.4                       315
# 393                      2.9                       191
# 394                     14.2                       316
#
#      Rainfall for month (in)  Rainfall for year (in)  \
# 390                     0.02                    0.59
# 391                     0.02                    0.59
# 392                     0.02                    0.59
# 393                     0.02                    0.59
# 394                     0.02                    0.59
#
#      Maximum rain per minute   Maximum temperature (°F)  \
# 390                      0.01                      39.1
# 391                      0.00                      48.8
# 392                      0.00                      48.3
# 393                      0.00                      44.6
# 394                      0.00                      36.9
#
#      Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 390                      14.3                    90                    40
# 391                      10.5                    86                    21
# 392                      15.4                    84                    23
# 393                      16.4                    83                    32
# 394                      20.0                    85                    34
#
#      Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 390             30.375             30.086                     15.0
# 391             30.387             30.012                     10.4
# 392             30.180             29.942                     18.4
# 393             30.138             29.787                      6.9
# 394             29.949             29.693                     24.2
#
#      Maximum gust speed (mph)  Maximum heat index (°F)
# 390                      22.0                     39.1
# 391                      14.0                     48.8
# 392                      26.0                     48.3
# 393                     255.0                     44.6
# 394                      36.0                     36.9

# %%
test['Average temperature (°F)'].mean().round(2)
# Out:
# 45.33

# %% [markdown]
# ### Find the range of averange temperature  on Dec 2010

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
df[df['Day'] == '31/12/2010']
# Out:
#             Day  Average temperature (°F)  Average humidity (%)  \
# 691  31/12/2010                       1.5                    53
#
#      Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 691                  -12.5                    30.0                      9.9
#
#      Average gustspeed (mph)  Average direction (°deg)  \
# 691                     14.3                       319
#
#      Rainfall for month (in)  Rainfall for year (in)  \
# 691                     0.58                   13.27
#
#      Maximum rain per minute   Maximum temperature (°F)  \
# 691                       0.0                       5.4
#
#      Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 691                      -1.4                    76                    34
#
#      Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 691             30.167             29.735                     27.6
#
#      Maximum gust speed (mph)  Maximum heat index (°F)
# 691                      40.3                      5.4

# %%
test = df[662:692]
test
# Out:
#             Day  Average temperature (°F)  Average humidity (%)  \
# 662   2/12/2010                      42.2                    39
# 663   3/12/2010                      44.8                    31
# 664   4/12/2010                      31.3                    62
# 665   5/12/2010                      28.8                    67
# 666   6/12/2010                      34.3                    62
# 667   7/12/2010                      34.3                    40
# 668   8/12/2010                      40.4                    26
# 669   9/12/2010                      39.6                    37
# 670  10/12/2010                      35.9                    47
# 671  11/12/2010                      25.2                    41
# 672  12/12/2010                      34.8                    50
# 673  13/12/2010                      45.8                    27
# 674  14/12/2010                      46.3                    26
# 675  15/12/2010                      34.1                    55
# 676  16/12/2010                      20.2                    62
# 677  17/12/2010                      15.7                    73
# 678  18/12/2010                      29.7                    61
# 679  19/12/2010                      36.5                    71
# 680  20/12/2010                      33.9                    83
# 681  21/12/2010                      25.0                    79
# 682  22/12/2010                      25.1                    84
# 683  23/12/2010                      32.9                    71
# 684  24/12/2010                      24.4                    80
# 685  25/12/2010                      24.1                    63
# 686  26/12/2010                      35.4                    40
# 687  27/12/2010                      31.4                    34
# 688  28/12/2010                      31.7                    28
# 689  29/12/2010                      35.5                    37
# 690  30/12/2010                      17.5                    71
# 691  31/12/2010                       1.5                    53
#
#      Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 662                   18.2                    30.0                     12.6
# 663                   15.9                    29.8                     13.8
# 664                   18.0                    30.2                      6.0
# 665                   18.9                    30.4                      2.7
# 666                   21.4                    30.3                      4.6
# 667                   12.0                    30.2                      7.8
# 668                    7.4                    30.1                     10.6
# 669                   14.9                    29.9                     15.3
# 670                   17.5                    29.8                     10.4
# 671                    4.6                    30.2                      7.2
# 672                   17.4                    30.2                     10.4
# 673                   13.6                    29.9                     19.5
# 674                   12.3                    29.6                     18.5
# 675                   18.5                    29.6                     10.2
# 676                    8.5                    30.1                      3.7
# 677                    8.5                    30.2                      1.7
# 678                   17.5                    29.9                      6.1
# 679                   27.8                    29.6                      4.5
# 680                   29.2                    29.6                      3.0
# 681                   19.3                    30.1                      2.3
# 682                   20.8                    30.3                      1.3
# 683                   24.0                    30.0                      3.1
# 684                   18.7                    30.4                      1.2
# 685                   10.7                    30.5                      0.6
# 686                   11.2                    30.0                      8.1
# 687                    5.9                    30.0                     14.3
# 688                    1.1                    29.9                      9.5
# 689                   10.5                    29.2                     16.1
# 690                    9.3                    29.4                      3.7
# 691                  -12.5                    30.0                      9.9
#
#      Average gustspeed (mph)  Average direction (°deg)  \
# 662                     19.0                       310
# 663                     17.1                       301
# 664                      7.9                       320
# 665                      4.1                        68
# 666                      7.0                       318
# 667                     11.9                       322
# 668                     15.5                       308
# 669                     22.5                       315
# 670                     16.0                       321
# 671                     11.4                       329
# 672                     15.5                       320
# 673                     28.5                       315
# 674                     32.6                       314
# 675                     14.7                       313
# 676                      6.1                        88
# 677                      3.1                       111
# 678                      8.9                       326
# 679                      6.5                       311
# 680                      4.9                        88
# 681                      3.6                        86
# 682                      1.8                        37
# 683                      7.4                       341
# 684                      2.1                        52
# 685                      1.4                        78
# 686                     17.9                       325
# 687                     21.2                       327
# 688                     13.6                       319
# 689                     25.4                       315
# 690                      5.7                       102
# 691                     14.3                       319
#
#      Rainfall for month (in)  Rainfall for year (in)  \
# 662                     0.00                   12.69
# 663                     0.00                   12.69
# 664                     0.00                   12.69
# 665                     0.00                   12.69
# 666                     0.00                   12.69
# 667                     0.00                   12.69
# 668                     0.00                   12.69
# 669                     0.00                   12.69
# 670                     0.00                   12.69
# 671                     0.00                   12.69
# 672                     0.00                   12.69
# 673                     0.00                   12.69
# 674                     0.00                   12.69
# 675                     0.01                   12.70
# 676                     0.01                   12.70
# 677                     0.01                   12.70
# 678                     0.01                   12.70
# 679                     0.13                   12.82
# 680                     0.42                   13.11
# 681                     0.49                   13.18
# 682                     0.57                   13.26
# 683                     0.57                   13.26
# 684                     0.58                   13.27
# 685                     0.58                   13.27
# 686                     0.58                   13.27
# 687                     0.58                   13.27
# 688                     0.58                   13.27
# 689                     0.58                   13.27
# 690                     0.58                   13.27
# 691                     0.58                   13.27
#
#      Maximum rain per minute   Maximum temperature (°F)  \
# 662                      0.00                      48.8
# 663                      0.00                      46.2
# 664                      0.00                      46.0
# 665                      0.00                      43.1
# 666                      0.00                      48.1
# 667                      0.00                      46.2
# 668                      0.00                      49.2
# 669                      0.00                      44.0
# 670                      0.00                      43.4
# 671                      0.00                      29.0
# 672                      0.00                      46.7
# 673                      0.00                      53.2
# 674                      0.00                      52.2
# 675                      0.01                      44.3
# 676                      0.00                      29.1
# 677                      0.00                      24.1
# 678                      0.00                      38.9
# 679                      0.01                      41.8
# 680                      0.01                      37.5
# 681                      0.01                      28.7
# 682                      0.02                      39.2
# 683                      0.00                      46.0
# 684                      0.01                      38.2
# 685                      0.00                      51.4
# 686                      0.00                      51.7
# 687                      0.00                      36.9
# 688                      0.00                      41.5
# 689                      0.00                      39.3
# 690                      0.00                      33.4
# 691                      0.00                       5.4
#
#      Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 662                      36.4                    58                    28
# 663                      42.3                    41                    28
# 664                      21.8                    89                    28
# 665                      18.8                    86                    45
# 666                      18.1                    87                    27
# 667                      23.0                    60                    23
# 668                      23.9                    41                    15
# 669                      29.5                    57                    25
# 670                      28.1                    85                    32
# 671                      17.0                    57                    31
# 672                      16.7                    66                    31
# 673                      42.6                    42                    16
# 674                      42.1                    41                    18
# 675                      22.9                    88                    27
# 676                      10.5                    84                    33
# 677                      10.0                    83                    53
# 678                      11.1                    83                    40
# 679                      32.3                    93                    52
# 680                      28.1                    92                    54
# 681                      22.3                    87                    54
# 682                      17.7                    90                    68
# 683                      19.2                    92                    44
# 684                      14.1                    89                    57
# 685                       8.4                    86                    17
# 686                      16.5                    77                    15
# 687                      27.6                    50                    24
# 688                      18.0                    51                    17
# 689                      32.8                    50                    15
# 690                      -1.2                    85                    44
# 691                      -1.4                    76                    34
#
#      Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 662             30.126             29.826                     31.1
# 663             29.851             29.802                     31.1
# 664             30.430             29.828                     16.1
# 665             30.487             30.267                     11.5
# 666             30.465             30.008                     17.3
# 667             30.382             29.951                     25.3
# 668             30.282             29.817                     26.5
# 669             29.998             29.766                     34.5
# 670             29.998             29.645                     25.3
# 671             30.425             29.947                     16.1
# 672             30.425             29.856                     28.8
# 673             29.975             29.770                     35.7
# 674             29.793             29.220                    169.1
# 675             29.942             29.362                     27.6
# 676             30.317             29.936                     19.6
# 677             30.329             30.131                      8.1
# 678             30.166             29.685                     19.6
# 679             29.720             29.418                     16.1
# 680             29.879             29.388                     10.4
# 681             30.318             29.846                      8.1
# 682             30.406             30.072                     11.5
# 683             30.191             29.850                    170.2
# 684             30.598             30.185                      6.9
# 685             30.719             30.255                      5.8
# 686             30.255             29.712                    120.8
# 687             30.177             29.752                     27.6
# 688             30.149             29.592                     24.2
# 689             29.592             29.036                    170.2
# 690             29.748             29.126                     12.7
# 691             30.167             29.735                     27.6
#
#      Maximum gust speed (mph)  Maximum heat index (°F)
# 662                      43.7                     48.8
# 663                      44.9                     46.2
# 664                      20.7                     46.0
# 665                      13.8                     43.1
# 666                      26.5                     48.1
# 667                      34.5                     46.2
# 668                      36.8                     49.2
# 669                      49.5                     44.0
# 670                      38.0                     43.4
# 671                      26.5                     29.0
# 672                      46.0                     46.7
# 673                      57.5                     53.2
# 674                     255.3                     52.2
# 675                      42.6                     44.3
# 676                      29.9                     29.1
# 677                      11.5                     24.1
# 678                      25.3                     38.9
# 679                      21.9                     41.8
# 680                      13.8                     37.5
# 681                      11.5                     28.7
# 682                      16.1                     39.2
# 683                     255.3                     46.0
# 684                      10.4                     38.2
# 685                      10.4                     51.4
# 686                     255.3                     51.7
# 687                      41.4                     36.9
# 688                      32.2                     41.5
# 689                     255.3                     39.3
# 690                      18.4                     33.4
# 691                      40.3                      5.4

# %%
test['Average temperature (°F)'].max()
# Out:
# 46.3

# %%
test['Average temperature (°F)'].min()
# Out:
# 1.5

# %%
test['Average temperature (°F)'].max() - test['Average temperature (°F)'].min()
# Out:
# 44.8

# %% [markdown]
# ### Out of all available records which day has the highest difference between maximum_pressure and minimum_pressure
#     - assign the date in string format as 'yyyy-mm-dd'. Make sure you enclose it with single quote

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
df.columns
# Out:
# Index(['Day', 'Average temperature (°F)', 'Average humidity (%)',
#        'Average dewpoint (°F)', 'Average barometer (in)',
#        'Average windspeed (mph)', 'Average gustspeed (mph)',
#        'Average direction (°deg)', 'Rainfall for month (in)',
#        'Rainfall for year (in)', 'Maximum rain per minute ',
#        'Maximum temperature (°F)', 'Minimum temperature (°F)',
#        'Maximum humidity (%)', 'Minimum humidity (%)', 'Maximum pressure ',
#        'Minimum pressure ', 'Maximum windspeed (mph)',
#        'Maximum gust speed (mph)', 'Maximum heat index (°F)'],
#       dtype='object')

# %%
test = df[['Day', 'Maximum pressure ', 'Minimum pressure ']]
test.head()
# Out:
#          Day  Maximum pressure   Minimum pressure
# 0  1/01/2009             29.762             29.596
# 1  2/01/2009             29.669             29.268
# 2  3/01/2009             30.232             29.260
# 3  4/01/2009             30.566             30.227
# 4  5/01/2009             30.233             29.568

# %%
test['pressure_range'] = test['Maximum pressure '] - test['Minimum pressure ']
test.head()
# Out:
# /home/user/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          Day  Maximum pressure   Minimum pressure   pressure_range
# 0  1/01/2009             29.762             29.596           0.166
# 1  2/01/2009             29.669             29.268           0.401
# 2  3/01/2009             30.232             29.260           0.972
# 3  4/01/2009             30.566             30.227           0.339
# 4  5/01/2009             30.233             29.568           0.665

# %%
test['pressure_range'].max()
# Out:
# 16.602000000000004

# %%
test[test['pressure_range'] == test['pressure_range'].max()]
# Out:
#              Day  Maximum pressure   Minimum pressure   pressure_range
# 3067  23/03/2018             29.868             13.266          16.602

# %% [markdown]
# ### How many days falls under median (i.e equal to median value) of barrometer reading.

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
test = df[['Day', 'Average barometer (in)']]
test.head()
# Out:
#          Day  Average barometer (in)
# 0  1/01/2009                    29.7
# 1  2/01/2009                    29.5
# 2  3/01/2009                    29.7
# 3  4/01/2009                    30.4
# 4  5/01/2009                    29.9

# %%
test['Average barometer (in)'].median()
# Out:
# 29.9

# %%
test = test[test['Average barometer (in)'] == test['Average barometer (in)'].median()]
test
# Out:
#              Day  Average barometer (in)
# 4      5/01/2009                    29.9
# 21    22/01/2009                    29.9
# 24    25/01/2009                    29.9
# 30    31/01/2009                    29.9
# 36     6/02/2009                    29.9
# 38     8/02/2009                    29.9
# 53    23/02/2009                    29.9
# 60     2/03/2009                    29.9
# 64     6/03/2009                    29.9
# 79    24/03/2009                    29.9
# 83    28/03/2009                    29.9
# 88     2/04/2009                    29.9
# 98    12/04/2009                    29.9
# 99    13/04/2009                    29.9
# 102   16/04/2009                    29.9
# 108   22/04/2009                    29.9
# 114   28/04/2009                    29.9
# 116   30/04/2009                    29.9
# 118    2/05/2009                    29.9
# 119    3/05/2009                    29.9
# 127   11/05/2009                    29.9
# 137   21/05/2009                    29.9
# 138   22/05/2009                    29.9
# 142   26/05/2009                    29.9
# 146   30/05/2009                    29.9
# 151    4/06/2009                    29.9
# 159   12/06/2009                    29.9
# 163   16/06/2009                    29.9
# 171   24/06/2009                    29.9
# 174   27/06/2009                    29.9
# ...          ...                     ...
# 3015   7/01/2018                    29.9
# 3026  18/01/2018                    29.9
# 3040   2/02/2018                    29.9
# 3053  15/02/2018                    29.9
# 3055  17/02/2018                    29.9
# 3065  27/02/2018                    29.9
# 3066  28/02/2018                    29.9
# 3081   6/04/2018                    29.9
# 3098  23/04/2018                    29.9
# 3108   3/05/2018                    29.9
# 3112   7/05/2018                    29.9
# 3120  15/05/2018                    29.9
# 3124  19/05/2018                    29.9
# 3138   2/06/2018                    29.9
# 3139   3/06/2018                    29.9
# 3179  13/07/2018                    29.9
# 3182  16/07/2018                    29.9
# 3187  26/07/2018                    29.9
# 3190  29/07/2018                    29.9
# 3192  31/07/2018                    29.9
# 3201   9/08/2018                    29.9
# 3202  10/08/2018                    29.9
# 3211  19/08/2018                    29.9
# 3213  21/08/2018                    29.9
# 3214  22/08/2018                    29.9
# 3243  22/09/2018                    29.9
# 3246  25/09/2018                    29.9
# 3249  28/09/2018                    29.9
# 3260   9/10/2018                    29.9
# 3279  28/10/2018                    29.9
#
# [534 rows x 2 columns]

# %% [markdown]
# ### Out of all the available records how many days are within one standard deviation of average temperaturem

# %%
df.head()
# Out:
#          Day  Average temperature (°F)  Average humidity (%)  \
# 0  1/01/2009                      37.8                    35
# 1  2/01/2009                      43.2                    32
# 2  3/01/2009                      25.7                    60
# 3  4/01/2009                       9.3                    67
# 4  5/01/2009                      23.5                    30
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# 0                     36.8                       274                      0.0
# 1                     18.0                       240                      0.0
# 2                     12.2                       290                      0.0
# 3                      4.5                        47                      0.0
# 4                     23.1                       265                      0.0
#
#    Rainfall for year (in)  Maximum rain per minute   Maximum temperature (°F)  \
# 0                     0.0                       0.0                      40.1
# 1                     0.0                       0.0                      52.8
# 2                     0.0                       0.0                      41.2
# 3                     0.0                       0.0                      19.4
# 4                     0.0                       0.0                      30.3
#
#    Minimum temperature (°F)  Maximum humidity (%)  Minimum humidity (%)  \
# 0                      34.5                    44                    27
# 1                      37.5                    43                    16
# 2                       6.7                    89                    35
# 3                      -0.0                    79                    35
# 4                      15.1                    56                    13
#
#    Maximum pressure   Minimum pressure   Maximum windspeed (mph)  \
# 0             29.762             29.596                     41.4
# 1             29.669             29.268                     35.7
# 2             30.232             29.260                     25.3
# 3             30.566             30.227                     12.7
# 4             30.233             29.568                     38.0
#
#    Maximum gust speed (mph)  Maximum heat index (°F)
# 0                      59.0                     40.1
# 1                      51.0                     52.8
# 2                      38.0                     41.2
# 3                      20.0                     32.0
# 4                      53.0                     32.0

# %%
test = df[['Day', 'Average temperature (°F)']]
test.head()
# Out:
#          Day  Average temperature (°F)
# 0  1/01/2009                      37.8
# 1  2/01/2009                      43.2
# 2  3/01/2009                      25.7
# 3  4/01/2009                       9.3
# 4  5/01/2009                      23.5

# %%
test['Average temperature (°F)'].std()
# Out:
# 15.188164868884014

# %%
test['Average temperature (°F)'].mean()
# Out:
# 45.16289634146341

# %%
x = test['Average temperature (°F)'].mean() - test['Average temperature (°F)'].std()
y = test['Average temperature (°F)'].mean() + test['Average temperature (°F)'].std()
print(x)
print(y)
# Out:
# 29.974731472579393
# 60.351061210347424

# %%
test1 = test[test['Average temperature (°F)'] >= x]
test1
# Out:
#              Day  Average temperature (°F)
# 0      1/01/2009                      37.8
# 1      2/01/2009                      43.2
# 6      7/01/2009                      34.2
# 7      8/01/2009                      42.1
# 8      9/01/2009                      30.3
# 10    11/01/2009                      30.1
# 12    13/01/2009                      32.4
# 13    14/01/2009                      33.1
# 14    15/01/2009                      35.7
# 15    16/01/2009                      41.6
# 16    17/01/2009                      40.9
# 17    18/01/2009                      43.4
# 18    19/01/2009                      46.6
# 19    20/01/2009                      40.0
# 20    21/01/2009                      48.2
# 21    22/01/2009                      44.8
# 23    24/01/2009                      35.4
# 29    30/01/2009                      36.0
# 30    31/01/2009                      38.3
# 31     1/02/2009                      30.8
# 32     2/02/2009                      33.0
# 33     3/02/2009                      38.6
# 34     4/02/2009                      43.3
# 35     5/02/2009                      45.6
# 36     6/02/2009                      33.4
# 37     7/02/2009                      34.2
# 38     8/02/2009                      31.5
# 39     9/02/2009                      31.2
# 46    16/02/2009                      38.9
# 47    17/02/2009                      32.5
# ...          ...                       ...
# 3247  26/09/2018                      48.1
# 3248  27/09/2018                      58.0
# 3249  28/09/2018                      39.4
# 3250  29/09/2018                      57.6
# 3251  30/09/2018                      53.7
# 3252   1/10/2018                      56.7
# 3253   2/10/2018                      60.4
# 3254   3/10/2018                      59.8
# 3255   4/10/2018                      48.6
# 3256   5/10/2018                      50.0
# 3257   6/10/2018                      38.7
# 3258   7/10/2018                      38.6
# 3259   8/10/2018                      32.6
# 3260   9/10/2018                      31.2
# 3262  11/10/2018                      33.3
# 3263  12/10/2018                      44.1
# 3264  13/10/2018                      46.3
# 3267  16/10/2018                      31.1
# 3268  17/10/2018                      34.7
# 3269  18/10/2018                      40.3
# 3270  19/10/2018                      44.9
# 3271  20/10/2018                      40.7
# 3272  21/10/2018                      48.9
# 3273  22/10/2018                      45.3
# 3274  23/10/2018                      43.8
# 3275  24/10/2018                      45.9
# 3276  25/10/2018                      46.7
# 3277  26/10/2018                      48.4
# 3278  27/10/2018                      53.3
# 3279  28/10/2018                      49.4
#
# [2731 rows x 2 columns]

# %%
#2731
test2 = test1[test['Average temperature (°F)'] <= y]
test2
# Out:
# /home/user/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              Day  Average temperature (°F)
# 0      1/01/2009                      37.8
# 1      2/01/2009                      43.2
# 6      7/01/2009                      34.2
# 7      8/01/2009                      42.1
# 8      9/01/2009                      30.3
# 10    11/01/2009                      30.1
# 12    13/01/2009                      32.4
# 13    14/01/2009                      33.1
# 14    15/01/2009                      35.7
# 15    16/01/2009                      41.6
# 16    17/01/2009                      40.9
# 17    18/01/2009                      43.4
# 18    19/01/2009                      46.6
# 19    20/01/2009                      40.0
# 20    21/01/2009                      48.2
# 21    22/01/2009                      44.8
# 23    24/01/2009                      35.4
# 29    30/01/2009                      36.0
# 30    31/01/2009                      38.3
# 31     1/02/2009                      30.8
# 32     2/02/2009                      33.0
# 33     3/02/2009                      38.6
# 34     4/02/2009                      43.3
# 35     5/02/2009                      45.6
# 36     6/02/2009                      33.4
# 37     7/02/2009                      34.2
# 38     8/02/2009                      31.5
# 39     9/02/2009                      31.2
# 46    16/02/2009                      38.9
# 47    17/02/2009                      32.5
# ...          ...                       ...
# 3246  25/09/2018                      47.6
# 3247  26/09/2018                      48.1
# 3248  27/09/2018                      58.0
# 3249  28/09/2018                      39.4
# 3250  29/09/2018                      57.6
# 3251  30/09/2018                      53.7
# 3252   1/10/2018                      56.7
# 3254   3/10/2018                      59.8
# 3255   4/10/2018                      48.6
# 3256   5/10/2018                      50.0
# 3257   6/10/2018                      38.7
# 3258   7/10/2018                      38.6
# 3259   8/10/2018                      32.6
# 3260   9/10/2018                      31.2
# 3262  11/10/2018                      33.3
# 3263  12/10/2018                      44.1
# 3264  13/10/2018                      46.3
# 3267  16/10/2018                      31.1
# 3268  17/10/2018                      34.7
# 3269  18/10/2018                      40.3
# 3270  19/10/2018                      44.9
# 3271  20/10/2018                      40.7
# 3272  21/10/2018                      48.9
# 3273  22/10/2018                      45.3
# 3274  23/10/2018                      43.8
# 3275  24/10/2018                      45.9
# 3276  25/10/2018                      46.7
# 3277  26/10/2018                      48.4
# 3278  27/10/2018                      53.3
# 3279  28/10/2018                      49.4
#
# [2092 rows x 2 columns]
