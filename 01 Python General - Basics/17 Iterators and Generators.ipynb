# %% [markdown]
# # Iterators
# - An Iterator is an object, which allows a programmer to traverse through all the elements of a collection, regardless of its specific implementation.
# - Values of an Iterator can be accessed only once and in sequential order.
# - iterator is a list like object, but doesnot have list options like slicing, etc.
# - iterator can be generated by **iter** function

# %%
x = [6, 3, 1]
s = iter(x)            
print(next(s))      # -> 6
# Out:
# 6

# %%
print(next(s))      # -> 3
# Out:
# 3

# %%
print(next(s))      # -> 1
# Out:
# 1

# %%
print(next(s))      # -> StopIteration Error
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 print(next(s))
#
# StopIteration:

# %%
lis = [1, 2, 3, 4]
ite = iter(lis)
for i in ite:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Working of For Loop

# %%
x = iter([1, 2, 3, 4])
while True:
    try:
        print(next(x))
    except StopIteration:
        break
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # Generators
# - A Generator object is an iterator, whose values are created at the time of accessing them.
# - A generator can be obtained either from a generator expression or a generator function.
# ![Difference between Function and Iterators](https://github.com/abdurahimank/Python-Tutorial/blob/main/images/iterator_img_1.gif)

# %%
x = [6, 3, 1]
g = (i**2 for i in x) # generator expression
print(next(g))
# Out:
# 36

# %%
print(next(g))
# Out:
# 9

# %%
print(next(g))
# Out:
# 1

# %%
def gen_number():  # generator function
    x = [6, 3, 1]
    for i in x:
        yield i**2
x = gen_number()
next(x)
# Out:
# 36

# %%
next(x)
# Out:
# 9

# %%
next(x)
# Out:
# 1

# %%
type(gen_number())
# Out:
# generator

# %%
def generator_123():
    yield 1
    yield 2
    yield 3
print(type(generator_123()))
# Out:
# <class 'generator'>

# %%
gen1 = generator_123()

# %%
next(gen1)
# Out:
# 1

# %%
next(gen1)
# Out:
# 2

# %%
next(gen1)
# Out:
# 3
