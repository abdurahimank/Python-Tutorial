# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplot(1, 2, 1)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.suptitle('fsfs')
plt.show()
