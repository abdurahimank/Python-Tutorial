# %% [markdown]
# # Python Operators
# - Arithmetic operators
# - Assignment operators
# - Comparison operators
# - Logical operators
# - Identity operators
# - Membership operators
# - Bitwise operators

# %%
print(11 / 2)  # Normal division
print(11 % 2)  # Remainder division/ Modulus
print(11 // 2)  # Floor division/ Integer division
print(11 ** 2)  # Exponentiation
# Out:
# 5.5
# 1
# 5
# 121

# %% [markdown]
# #### Bitwise Operator
# ![0-0-1.jpg](attachment:0-0-1.jpg)
